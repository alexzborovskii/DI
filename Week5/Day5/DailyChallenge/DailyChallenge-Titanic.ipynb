# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1

# %%
df = pd.read_csv('Titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # 2

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # 3

# %%
sns.set()
figure, axes = plt.subplots()
axes.pie(df.Sex.value_counts(), labels=df['Sex'].unique(), hatch=['O.O', '.||.'])
# Out:
# ([<matplotlib.patches.Wedge at 0x2359a5bbb50>,
# ...
#  [Text(-0.4919454136803954, 0.9838646807152012, 'male'),
#   Text(0.4919455057964525, -0.9838646346559433, 'female')])

# %%
figure, axes = plt.subplots()
axes.hist(df['Age'])
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
surv = df.groupby('Survived')['Survived'].count()
figure, axes = plt.subplots()
axes.bar(['Survived', 'Didn`t survive'], surv)
# Out:
# <BarContainer object of 2 artists>

# %%
surv_sex = df.groupby(['Sex', 'Survived']).count().reset_index()
surv_sex
# Out:
#       Sex  Survived  PassengerId  Pclass  Name  Age  SibSp  Parch  Ticket  \
# 0  female         0           81      81    81   64     81     81      81
# 1  female         1          233     233   233  197    233    233     233
# 2    male         0          468     468   468  360    468    468     468
# 3    male         1          109     109   109   93    109    109     109
#
#    Fare  Cabin  Embarked
# 0    81      6        81
# 1   233     91       231
# 2   468     62       468
# 3   109     45       109

# %%
sex = surv_sex['Sex'].unique()

bottom = surv_sex['Survived']==0
bottom_val = surv_sex[bottom]['PassengerId']
bottom_val

upper = surv_sex['Survived']==1
upper_val = surv_sex[upper]['PassengerId']
upper
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# Name: Survived, dtype: bool

# %%
figure, axes = plt.subplots()

axes.bar(sex, bottom_val, color='r')
axes.bar(sex, upper_val, bottom=bottom_val, color='g')
# Out:
# <BarContainer object of 2 artists>

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
figure, axes = plt.subplots()
axes.scatter( df['Age'], df['Fare'])

# %% [markdown]
# # 4

# %% [markdown]
# ### age nan

# %%
df['Age'] = pd.to_numeric(df['Age'], errors='coerce')

# %%
df['Age'].head(10)
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# 5     NaN
# 6    54.0
# 7     2.0
# 8    27.0
# 9    14.0
# Name: Age, dtype: float64

# %%
mean_value=df['Age'].mean()

# %%
df['Age'].fillna(value=mean_value, inplace=True)

# %%
df['Age'].head(10)
# Out:
# 0    22.000000
# 1    38.000000
# 2    26.000000
# 3    35.000000
# 4    35.000000
# 5    29.699118
# 6    54.000000
# 7     2.000000
# 8    27.000000
# 9    14.000000
# Name: Age, dtype: float64

# %% [markdown]
# ### fare norm

# %%
df['Fare'].head()
# Out:
# 0     7.2500
# 1    71.2833
# 2     7.9250
# 3    53.1000
# 4     8.0500
# Name: Fare, dtype: float64

# %%
df['Fare_norm'] = (df['Fare'] - df['Fare'].min()) / (df['Fare'].max() - df['Fare'].min())

# %%
df['Fare'].head()
# Out:
# 0     7.2500
# 1    71.2833
# 2     7.9250
# 3    53.1000
# 4     8.0500
# Name: Fare, dtype: float64

# %% [markdown]
# ### sex numerical

# %%
df['Sex']
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object

# %%
one_hot = pd.get_dummies(df['Sex'], dtype=int)

# %%
df = df.join(one_hot)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %% [markdown]
# # 5

# %% [markdown]
# ### survival rate by genders

# %%
surv_sex = df.groupby(['Survived', 'Sex']).count().reset_index()
surv_sex
# Out:
#    Survived     Sex  PassengerId  Pclass  Name  Age  SibSp  Parch  Ticket  \
# 0         0  female           81      81    81   81     81     81      81
# 1         0    male          468     468   468  468    468    468     468
# 2         1  female          233     233   233  233    233    233     233
# 3         1    male          109     109   109  109    109    109     109
#
#    Fare  Cabin  Embarked  Fare_norm  female  male
# 0    81      6        81         81      81    81
# 1   468     62       468        468     468   468
# 2   233     91       231        233     233   233
# 3   109     45       109        109     109   109

# %%
fem_surv = surv_sex.loc[(surv_sex['Survived'] == 1) & (surv_sex['Sex'] == 'female')]['PassengerId'].iloc[0]
mal_surv = surv_sex.loc[(surv_sex['Survived'] == 1) & (surv_sex['Sex'] == 'male')]['PassengerId'].iloc[0]

# %%
fem_amount = fem_surv + surv_sex.loc[(surv_sex['Survived'] == 0) & (surv_sex['Sex'] == 'female')]['PassengerId'].iloc[0]
mal_amount = mal_surv + surv_sex.loc[(surv_sex['Survived'] == 0) & (surv_sex['Sex'] == 'male')]['PassengerId'].iloc[0]

# %%
# FEMALE SURVIVING RATE
fem_serv_rate = fem_surv / fem_amount
fem_serv_rate
# Out:
# 0.7420382165605095

# %%
# MALE SURVIVING RATE ;(
mal_serv_rate = mal_surv / mal_amount
mal_serv_rate
# Out:
# 0.18890814558058924

# %% [markdown]
# ### survival rate by passenger classes

# %%
surv_pc = df.groupby(['Survived', 'Pclass']).count().reset_index()
surv_pc
# Out:
#    Survived  Pclass  PassengerId  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# 0         0       1           80    80   80   80     80     80      80    80
# 1         0       2           97    97   97   97     97     97      97    97
# 2         0       3          372   372  372  372    372    372     372   372
# 3         1       1          136   136  136  136    136    136     136   136
# 4         1       2           87    87   87   87     87     87      87    87
# 5         1       3          119   119  119  119    119    119     119   119
#
#    Cabin  Embarked  Fare_norm  female  male
# 0     59        80         80      80    80
# 1      3        97         97      97    97
# 2      6       372        372     372   372
# 3    117       134        136     136   136
# 4     13        87         87      87    87
# 5      6       119        119     119   119

# %%
firstpc_surv = surv_pc.loc[(surv_pc['Survived'] == 1) & (surv_pc['Pclass'] == 1)]['PassengerId'].iloc[0]
secondpc_surv = surv_pc.loc[(surv_pc['Survived'] == 1) & (surv_pc['Pclass'] == 2)]['PassengerId'].iloc[0]
thirdpc_surv = surv_pc.loc[(surv_pc['Survived'] == 1) & (surv_pc['Pclass'] == 3)]['PassengerId'].iloc[0]


firstpc_amount = firstpc_surv + surv_pc.loc[(surv_pc['Survived'] == 0) & (surv_pc['Pclass'] == 1)]['PassengerId'].iloc[0]
secondpc_amount = secondpc_surv + surv_pc.loc[(surv_pc['Survived'] == 0) & (surv_pc['Pclass'] == 2)]['PassengerId'].iloc[0]
thirdpc_amount = thirdpc_surv + surv_pc.loc[(surv_pc['Survived'] == 0) & (surv_pc['Pclass'] == 3)]['PassengerId'].iloc[0]

firstpc_serv_rate = firstpc_surv / firstpc_amount
secondpc_serv_rate = secondpc_surv / secondpc_amount
thirdpc_serv_rate = thirdpc_surv / thirdpc_amount

# %%
# SURVIVAL RATES 1-2-3 Passanger classes
print(firstpc_serv_rate, secondpc_serv_rate, thirdpc_serv_rate)
# Out:
# 0.6296296296296297 0.47282608695652173 0.24236252545824846

# %%
# PASSENGERS WITH MAX FARE
max_fare = df[df['Fare'] == df['Fare'].max()]['Name']
max_fare
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object
